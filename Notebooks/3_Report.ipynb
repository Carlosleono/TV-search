# %% [markdown]
# # Búsqueda de una televisión en Worten

# %% [markdown]
# En este proyecto se ha realizado una búsqueda de televisores en la tienda online de Worten aprovechando que estamos en la semana de black friday. Se han buscado 96 resultados de televisores teniendo y se ha hecho un análisis del precio para diferentes factores.

# %% [markdown]
# ### Distribución de precios por tecnología y resolución

# %% [markdown]
# En primer lugar se ha realizado un histograma de precios diferenciando por tecnología y resolución que se muestra a continuación. De aquí se puede observar como la mayoria de los televisores usan tecnología LCD-LED con una resolución de 4K Ultra HD. Además, se puede observar como la mayoría de las televisiones cuestan menos de 3.000€, aunque existen excepciones.

# %% [markdown]
# ![pricebytecandres.png](attachment:pricebytecandres.png)

# %% [markdown]
# ### Comparación de precios por marca

# %% [markdown]
# En este apartado se quiere evaluar qué marcas son más caras y que distribución tienen. Para ello, se ha dibujado un gráfico con el precio medio de las teles de cada marca donde se aprecia que LG, Samsung y Sony son las más caras.

# %% [markdown]
# ![pricebymarca.png](attachment:pricebymarca.png)

# %% [markdown]
# Para profundizar un poco más, se ha realizado un gráfico de cajas, en donde se puede apreciar que el precio medio de estas marcas es más alto sobre todo porque tienen outliers, pero su distribución no están diferente de la de las otras marcas

# %% [markdown]
# ![boxplotmarcabueno.png](attachment:boxplotmarcabueno.png)

# %% [markdown]
# ### Relación del precio con el tamaño

# %% [markdown]
# Llegados a este punto se quería comprobar la influencia del tamaño de pantalla en el precio. Para ello se ha realizado un gráfico de dispersión para las dos variables. Se puede observar como hay una relación de proporcionalidad directa entre estas dos variables.

# %% [markdown]
# ![pricebysizes.png](attachment:pricebysizes.png)

# %% [markdown]
# ### Selección de Televisión

# %% [markdown]
# Una vez hecho este estudio se hace un filtrado de las televisiones que no sean de las más caras (LG, Samsung y Sony), de un tamaño medio (55") y menores a 650€ para entrar en el presupuesto:

# %%
import pandas as pd
finalistas=pd.read_csv('../data/elegidas.csv')
finalistas.set_index('Unnamed: 0',inplace=True)
finalistas
# Out:
#                                                        Modelo  Precio  Tamaño  \
# Unnamed: 0
# 19          TV SMART TECH SMT55N30UC2M1B1 (LED - 55'' - 14...  359.99    55.0
# 33          TV HISENSE 55A7100F (LED - 55'' - 140 cm - 4K ...  419.99    55.0
# 36          TV XIAOMI MI P1 (LED - 55'' - 140 cm - 4K Ultr...  469.99    55.0
# 79          TV HISENSE 55U7QF (ULED Quantum Dot - 55'' - 1...  516.90    55.0
# 38          TV HISENSE 55A7GQ (QLED - 55'' - 140 cm - 4K U...  529.99    55.0
# 13          TV SILVER 410885 (LED - 55'' - 140 cm - 4K Ult...  537.09    55.0
#
#             Distancia Tecnología   Resolución Smart TV Sonido  Altavoces  \
# Unnamed: 0
# 19                NaN    LCD-LED  4K Ultra HD       Sí    16W        2.0
# 33               1.68    LCD-LED  4K Ultra HD       Sí    NaN        2.0
# 36               1.68    LCD-LED  4K Ultra HD       Sí     20        2.0
# 79               1.68    LCD-LED  4K Ultra HD       Sí   10 W        2.0
# ...
