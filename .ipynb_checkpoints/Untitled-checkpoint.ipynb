# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
import pandas as pd
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager

# %%
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)

# %%
driver= webdriver.Chrome('./chromedriver.exe')

tabla2 = []
precios = []
modelo = []
url2 = 'https://www.worten.es/'

driver.get(url2)
driver.implicitly_wait(2)

driver.find_element_by_css_selector("body > div.w-cookies-popup__wrapper > section > div.w-cookies-popup__footer > div.w-cookies-popup__footer__primary-button > button").click()
driver.find_element_by_css_selector("#search-input").send_keys("televisores")
driver.find_element_by_css_selector("#Autocomplete > section > div > div > ul > li:nth-child(1) > a > div > span:nth-child(2) > span > strong").click()

for pag in range(1,5):

    url= f'https://www.worten.es/search?query=televisores&page={pag}'
    driver.get(url)
    for i in range(1,25):
                                                              
        try: 
            modelo.append(driver.find_element_by_css_selector(f'#products-list-block > div:nth-child({i}) > div > a > div > div.w-product__description > div.w-product__title__wrapper > h3').text)
            precios.append(driver.find_element_by_css_selector(f'#products-list-block > div:nth-child({i}) > div > a > div > div.w-product__details > div:nth-child(2) > span.w-currentPrice.iss-current-price > span').text)
            driver.find_element_by_css_selector(f"#products-list-block > div:nth-child({i}) > div > a > div > div.w-product__description > div.w-product__title__wrapper > h3").click()
            tabla2.append(driver.find_element_by_css_selector("#maincontent > div > div.w-section__wrapper.w-section__container-center.w-margin-top > div > div > section.w-product-details.w-section__block.w-margin-top > div > div > div:nth-child(2)").text)
            
        except:
            print('hola')
            driver.find_element_by_css_selector("#twotabsearchtextbox").click()
            driver.find_element_by_css_selector("#nav-search-submit-button").click()
        driver.get(url)
        driver.implicitly_wait(2)
# Out:
# <ipython-input-93-d01bf687d1bf>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver= webdriver.Chrome('./chromedriver.exe')
# <ipython-input-93-d01bf687d1bf>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("body > div.w-cookies-popup__wrapper > section > div.w-cookies-popup__footer > div.w-cookies-popup__footer__primary-button > button").click()
# <ipython-input-93-d01bf687d1bf>:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#search-input").send_keys("televisores")
# <ipython-input-93-d01bf687d1bf>:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#Autocomplete > section > div > div > ul > li:nth-child(1) > a > div > span:nth-child(2) > span > strong").click()
# <ipython-input-93-d01bf687d1bf>:22: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   modelo.append(driver.find_element_by_css_selector(f'#products-list-block > div:nth-child({i}) > div > a > div > div.w-product__description > div.w-product__title__wrapper > h3').text)
# <ipython-input-93-d01bf687d1bf>:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   precios.append(driver.find_element_by_css_selector(f'#products-list-block > div:nth-child({i}) > div > a > div > div.w-product__details > div:nth-child(2) > span.w-currentPrice.iss-current-price > span').text)
# <ipython-input-93-d01bf687d1bf>:24: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector(f"#products-list-block > div:nth-child({i}) > div > a > div > div.w-product__description > div.w-product__title__wrapper > h3").click()
# <ipython-input-93-d01bf687d1bf>:25: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   tabla2.append(driver.find_element_by_css_selector("#maincontent > div > div.w-section__wrapper.w-section__container-center.w-margin-top > div > div > section.w-product-details.w-section__block.w-margin-top > div > div > div:nth-child(2)").text)
# hola
# <ipython-input-93-d01bf687d1bf>:29: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#twotabsearchtextbox").click()
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-93-d01bf687d1bf> in <module>
#      23             precios.append(driver.find_element_by_css_selector(f'#products-list-block > div:nth-child({i}) > div > a > div > div.w-product__details > div:nth-child(2) > span.w-currentPrice.iss-current-price > span').text)
# ---> 24             driver.find_element_by_css_selector(f"#products-list-block > div:nth-child({i}) > div > a > div > div.w-product__description > div.w-product__title__wrapper > h3").click()
#      25             tabla2.append(driver.find_element_by_css_selector("#maincontent > div > div.w-section__wrapper.w-section__container-center.w-margin-top > div > div > section.w-product-details.w-section__block.w-margin-top > div > div > div:nth-child(2)").text)
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     692         params['id'] = self._id
# --> 693         return self._parent.execute(command, params)
#     694
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     417         if response:
# --> 418             self.error_handler.check_response(response)
#     419             response['value'] = self._unwrap_value(
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#     244
#
# WebDriverException: Message: disconnected: Unable to receive message from renderer
#   (Session info: chrome=96.0.4664.45)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00F86903+2517251]
# 	Ordinal0 [0x00F1F8E1+2095329]
# 	Ordinal0 [0x00E22848+1058888]
# 	Ordinal0 [0x00E14FBF+1003455]
# 	Ordinal0 [0x00E146B8+1001144]
# 	Ordinal0 [0x00E27ED8+1081048]
# 	Ordinal0 [0x00E75E8E+1400462]
# 	Ordinal0 [0x00E6639B+1336219]
# 	Ordinal0 [0x00E427A7+1189799]
# 	Ordinal0 [0x00E43609+1193481]
# 	GetHandleVerifier [0x01115904+1577972]
# 	GetHandleVerifier [0x011C0B97+2279047]
# 	GetHandleVerifier [0x01016D09+534521]
# 	GetHandleVerifier [0x01015DB9+530601]
# 	Ordinal0 [0x00F24FF9+2117625]
# 	Ordinal0 [0x00F298A8+2136232]
# 	Ordinal0 [0x00F299E2+2136546]
# 	Ordinal0 [0x00F33541+2176321]
# 	BaseThreadInitThunk [0x7601FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77877A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77877A6E+238]
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-93-d01bf687d1bf> in <module>
#      27         except:
#      28             print('hola')
# ---> 29             driver.find_element_by_css_selector("#twotabsearchtextbox").click()
#      30             driver.find_element_by_css_selector("#nav-search-submit-button").click()
#      31         driver.get(url)
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_css_selector(self, css_selector)
#     800             stacklevel=2,
#     801         )
# --> 802         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     803
#     804     def find_elements_by_css_selector(self, css_selector) -> WebElement:
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#    1236             value = '[name="%s"]' % value
#    1237
# -> 1238         return self.execute(Command.FIND_ELEMENT, {
#    1239             'using': by,
#    1240             'value': value})['value']
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     416         response = self.command_executor.execute(driver_command, params)
#     417         if response:
# --> 418             self.error_handler.check_response(response)
#     419             response['value'] = self._unwrap_value(
#     420                 response.get('value', None))
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     241                 alert_text = value['alert'].get('text')
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#     244
#     245     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#twotabsearchtextbox"}
#   (Session info: chrome=96.0.4664.45)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00F86903+2517251]
# 	Ordinal0 [0x00F1F8E1+2095329]
# 	Ordinal0 [0x00E22848+1058888]
# 	Ordinal0 [0x00E4D448+1233992]
# 	Ordinal0 [0x00E4D63B+1234491]
# 	Ordinal0 [0x00E77812+1406994]
# 	Ordinal0 [0x00E6650A+1336586]
# 	Ordinal0 [0x00E75BBF+1399743]
# 	Ordinal0 [0x00E6639B+1336219]
# 	Ordinal0 [0x00E427A7+1189799]
# 	Ordinal0 [0x00E43609+1193481]
# 	GetHandleVerifier [0x01115904+1577972]
# 	GetHandleVerifier [0x011C0B97+2279047]
# 	GetHandleVerifier [0x01016D09+534521]
# 	GetHandleVerifier [0x01015DB9+530601]
# 	Ordinal0 [0x00F24FF9+2117625]
# 	Ordinal0 [0x00F298A8+2136232]
# 	Ordinal0 [0x00F299E2+2136546]
# 	Ordinal0 [0x00F33541+2176321]
# 	BaseThreadInitThunk [0x7601FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77877A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77877A6E+238]

# %%
modelo = modelo[:116]

# %%
teles= tabla2[:98]

# %%
len(teles)
# Out:
# 98

# %%
teles[0].split('\n')
# Out:
# ['Imagen',
#  'Diagonal de la pantalla',
#  "55'' (140 cm)",
#  'Distancia mínima de visualización',
#  '1.68',
#  'Tecnología del fabricante',
#  'OLED',
#  'Tipo de pantalla',
#  'OLED',
#  'Resolución',
#  '4K Ultra HD',
#  'Retroiluminación',
#  'Pixel Dimming',
#  'Procesador',
#  '4K ¿9 Gen4',
#  'Formatos HDR',
#  'HDR 10 Pro, HLG Pro',
#  'Modos de imagen',
#  'Modo Director',
#  'Tecnologías gaming',
#  'nVIDIA G-Sync Compatible, AMD FreeSync Compatible, HDR GiG, VRR / ALLM, Cloud Gaming Stadia, HDMI 2.1',
#  'Smart TV & Domótica',
#  'Smart TV',
#  'Sí',
#  'Sistema operativo',
#  'webOS 6.0',
#  'Aplicaciones',
#  'Apple TV | Netflix | YouTube | Movistart+ | Disney + | HBO | Prime Video | RTVE | Wuaki | FilmIn | Orange TV | AtresMedia Player | Google Play | GameFly | Spotify | El Pais TV | Bein Sports | LG TV Plus',
#  'Conexión con múltiples dispositivos',
#  'Airplay 2, Home Kit, Miracast',
#  'Compatible con asistentes inteligentes',
#  'Google Assistant, Alexa',
#  'Reconocimiento de voz',
#  'Sí, con el mando incluido',
#  'Sonido',
#  'Potencia de sonido total',
#  '40 W',
#  'Altavoces integrados',
#  '2.2',
#  'Subwoofer',
#  'Sí',
#  'Tecnologías audio',
#  'Dolby Atmos, AI Sound Pro',
#  'Conexiones',
#  'Bluetooth',
#  'Sí',
#  'N.º de entradas HDMI',
#  '4',
#  'N.º de puertos USB',
#  '3',
#  'Salida para auriculares',
#  'Sí',
#  'Otras conexiones',
#  'DVB-T2/T',
#  ' ']

# %%
import re
columnas = ['Modelo', 'Precio','Tamaño', 'Distancia', 'Tecnología', 'Resolución', 'Smart TV', 'Sonido', 'Altavoces', 'HDMI']
televisiones = []

for tele in teles:
    caracteristicas={}
    indice = teles.index(tele)
    caracteristicas['Modelo'] = modelo[indice]
    caracteristicas['Precio'] = precios[indice]
    listada = tele.split('\n')
    for caract in listada:
        try:
            ind=listada.index(caract)
            if re.match('.*iagonal.*', caract):
                caracteristicas['Tamaño'] = listada[ind+1]
            elif re.match('.*istancia.*', caract):
                caracteristicas['Distancia'] = listada[ind+1]
            elif re.match('Tipo de pantalla', caract):
                caracteristicas['Tecnología'] = listada[ind+1]
            elif re.match('Resolución', caract):
                caracteristicas['Resolución'] = listada[ind+1]
            elif re.match('Smart TV', caract):
                caracteristicas['Smart TV'] = listada[ind+1]
            elif re.match('Potencia de sonido.*', caract):
                caracteristicas['Sonido'] = listada[ind+1]
            elif re.match('Altavoces integrados', caract):
                caracteristicas['Altavoces'] = listada[ind+1]
            elif re.match('.*entradas HDMI', caract):
                caracteristicas['HDMI'] = listada[ind+1]
        except:
            print(caract)
    print(caracteristicas)
    televisiones.append(caracteristicas)
# Out:
# {'Modelo': "TV LG 55C15 (OLED - 55'' - 140 cm - 4K Ultra HD - Smart TV)", 'Precio': '1249,00€', 'Tamaño': "55'' (140 cm)", 'Distancia': '1.68', 'Tecnología': 'OLED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '40 W', 'Altavoces': '2.2', 'HDMI': '4'}
# {'Modelo': "TV LG 65C15 (OLED - 65'' - 165 cm - 4K Ultra HD - Smart TV)", 'Precio': '1599,00€', 'Tamaño': "65'' (165 cm)", 'Distancia': '1.98', 'Tecnología': 'OLED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '40 W', 'Altavoces': '2.2', 'HDMI': '4'}
# {'Modelo': "TV LG 48C15 (OLED - 48'' - 122 cm - 4K Ultra HD - Smart TV)", 'Precio': '1890,89€', 'Tamaño': "48'' (122 cm)", 'Distancia': '1.49', 'Tecnología': 'OLED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '40 W', 'Altavoces': '2.2', 'HDMI': '4'}
# {'Modelo': "TV LG 55G16 (OLED - 55'' - 140 cm - 4K Ultra HD - Smart TV)", 'Precio': '1495,00€', 'Tamaño': "55'' (140 cm)", 'Distancia': '1.68', 'Tecnología': 'OLED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '60 W', 'Altavoces': '4.2', 'HDMI': '4'}
# {'Modelo': "TV LG 55UP77006LB (LED - 55'' - 140 cm - 4K Ultra HD - Smart TV)", 'Precio': '469,00€', 'Tamaño': "55'' (140 cm)", 'Distancia': '1.68', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '2'}
# {'Modelo': "TV LG 55NANO756 (Nano Cell - 55'' - 140 cm - 4K Ultra HD - Smart TV)", 'Precio': '599,00€', 'Tamaño': "55'' (140 cm)", 'Distancia': '1.68', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV SMART TECH SMT40N30FC4U1B1 (LED - 40'' - 102 cm - Full HD - Smart Tv)", 'Precio': '235,99€', 'Tamaño': "40'' (102 cm)", 'Distancia': '1.5', 'Tecnología': 'LCD-LED', 'Resolución': 'Full HD', 'Smart TV': 'Sí', 'Sonido': '16W', 'Altavoces': '2', 'HDMI': '3'}
# {'Modelo': "TV HISENSE 58A7100F (LED - 58'' - 147 cm - 4K Ultra HD - Smart TV)", 'Precio': '429,99€', 'Tamaño': "58'' (147 cm)", 'Distancia': '1.77', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '16 W', 'Altavoces': '2', 'HDMI': '3'}
# {'Modelo': "TV LG 43UP77006LB (LED - 43'' - 109 cm - 4K Ultra HD - Smart TV)", 'Precio': '379,00€', 'Tamaño': "43'' (109 cm)", 'Distancia': '1.31', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '2'}
# {'Modelo': "TV LG 50UP77006LB (LED - 50'' 127 cm - 4K Ultra HD - Smart TV)", 'Precio': '449,00€', 'Tamaño': "50'' (127 cm)", 'Distancia': '1.52', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '2'}
# {'Modelo': "TV LG 65G16 (OLED - 65'' - 165 cm - 4K Ultra HD - Smart TV)", 'Precio': '1995,00€', 'Tamaño': "65'' (165 cm)", 'Distancia': '1.98', 'Tecnología': 'OLED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '60 W', 'Altavoces': '4.2', 'HDMI': '4'}
# {'Modelo': "TV LG 65UP77006LB (LED - 65'' - 165 cm - 4K Ultra HD - Smart TV)", 'Precio': '599,00€', 'Tamaño': "65'' (165 cm)", 'Distancia': '1.98', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '2'}
# {'Modelo': "TV LG 50NANO756 (Nano Cell - 50'' - 127 cm - 4K Ultra HD - Smart TV)", 'Precio': '499,00€', 'Tamaño': "50'' (127 cm)", 'Distancia': '1.52', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV SILVER 410885 (LED - 55'' - 140 cm - 4K Ultra HD - Smart TV)", 'Precio': '537,09€', 'Tamaño': "55'' (140 cm)", 'Distancia': '1.68', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV LG 77C15 (OLED - 77'' - 196 cm - 4K Ultra HD - Smart TV)", 'Precio': '6332,39€', 'Tamaño': "77'' (196 cm)", 'Distancia': '2.35', 'Tecnología': 'OLED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '40 W', 'Altavoces': '2.2', 'HDMI': '4'}
# {'Modelo': "TV SMART TECH SMT50S10UC2U2G1 (LED - 50'' - 127 cm - 4K Ultra HD - Smart Tv)", 'Precio': '329,99€', 'Tamaño': "50'' (127 cm)", 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '16W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV LG 75UP77006LB (LED - 75'' - 191 cm - 4K Ultra HD - Smart TV)", 'Precio': '789,99€', 'Tamaño': "75'' (191 cm)", 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '2'}
# {'Modelo': "TV LG 48A16LA (OLED - 48'' - 122 cm - 4K Ultra HD - Smart TV)", 'Precio': '849,00€', 'Tamaño': "48'' (122 cm)", 'Distancia': '1.49', 'Tecnología': 'OLED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV HISENSE 50A6BG (LED - 50'' - 127 cm - 4K Ultra HD - Smart TV)", 'Precio': '374,99€', 'Tamaño': "50'' (127 cm)", 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sistema operativo', 'Sonido': '16W', 'Altavoces': '2.0'}
# {'Modelo': "TV SMART TECH SMT55N30UC2M1B1 (LED - 55'' - 140 cm - 4K Ultra HD - Smart Tv)", 'Precio': '359,99€', 'Tamaño': "55'' (140 cm)", 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '16W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV LG 70UP77006LB (LED - 70'' - 179 cm - 4K Ultra HD - Smart TV)", 'Precio': '709,99€', 'Tamaño': "70'' (179 cm)", 'Distancia': '2.1', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '2'}
# {'Modelo': "TV LG 75NANO756 (Nano Cell - 75'' - 189 cm - 4K Ultra HD - Smart TV)", 'Precio': '979,00€', 'Tamaño': "75'' (189 cm)", 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV SILVER 410884 (LED - 50'' - 127 cm - 4K Ultra HD - Smart TV)", 'Precio': '397,30€', 'Tamaño': "50'' (127 cm)", 'Distancia': '1.52', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV LG 55UP81006 (LED - 55'' - 140 cm - 4K Ultra HD - Smart TV)", 'Precio': '519,99€', 'Tamaño': "55'' (140 cm)", 'Distancia': '1.68', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV SONY XR65A80J (OLED - 65'' - 165 cm - 4K Ultra HD - Smart TV)", 'Precio': '1845,00€', 'Tamaño': "65'' (165 cm)", 'Distancia': '1.98', 'Tecnología': 'OLED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '30 W', 'HDMI': '4'}
# {'Modelo': "TV HISENSE 100L5F (Láser - 100'' - 254 cm - 4K Ultra HD - Smart TV)", 'Precio': '2799,00€', 'Tamaño': "100'' (254 cm)", 'Distancia': '3.05', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '30 W', 'HDMI': '4'}
# {'Modelo': "TV LG 55A16LA (OLED - 55'' - 140 cm - 4K Ultra HD - Smart TV)", 'Precio': '895,00€', 'Tamaño': "55'' (140 cm)", 'Distancia': '1.68', 'Tecnología': 'OLED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV SONY XR55X90J (LED - 55'' - 140 cm - 4K Ultra HD - Smart TV)", 'Precio': '969,00€', 'Tamaño': "55'' (140 cm)", 'Distancia': '1.68', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '2.0', 'HDMI': '4'}
# {'Modelo': "TV SONY KD43X85J (LED - 43'' - 109 cm - 4K Ultra HD - Smart TV)", 'Precio': '659,99€', 'Tamaño': "43'' (109 cm)", 'Distancia': '1.31', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '4'}
# {'Modelo': "TV LG 55NANO926PB (Nano Cell - 55'' - 140 cm - 4K Ultra HD - Smart TV)", 'Precio': '779,99€', 'Tamaño': "55'' (140 cm)", 'Distancia': '1.68', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '40 W', 'Altavoces': '2.2', 'HDMI': '4'}
# {'Modelo': "TV LG 75NANO926PB (Nano Cell - 75'' - 191 cm - 4K Ultra HD - Smart TV)", 'Precio': '1499,00€', 'Tamaño': "75'' (191 cm)", 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '40 W', 'Altavoces': '2.2', 'HDMI': '4'}
# {'Modelo': "TV LG 43NANO756 (Nano Cell - 43'' - 109 cm - 4K Ultra HD - Smart TV)", 'Precio': '489,00€', 'Tamaño': "43'' (109 cm)", 'Distancia': '1.31', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV SONY XR65A90JAEP (OLED - 65'' - 165 cm - 4K Ultra HD - Smart TV)", 'Precio': '2749,00€', 'Tamaño': "65'' (165 cm)", 'Distancia': '1.98', 'Tecnología': 'OLED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '60 W', 'HDMI': '4'}
# {'Modelo': "TV HISENSE 55A7100F (LED - 55'' - 140 cm - 4K Ultra HD - Smart TV)", 'Precio': '419,99€', 'Tamaño': "55'' (140 cm)", 'Distancia': '1.68', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Altavoces': '2', 'HDMI': '3'}
# {'Modelo': "TV SONY XR77A80J (OLED - 77'' - 196 cm - 4K Ultra HD - Smart TV)", 'Precio': '2929,00€', 'Tamaño': "77'' (196 cm)", 'Distancia': '2.35', 'Tecnología': 'OLED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '50 W', 'HDMI': '4'}
# {'Modelo': "TV HISENSE 50A7100F (LED - 50'' - 127 cm - 4K Ultra HD - Smart TV)", 'Precio': '405,90€', 'Tamaño': "50'' (127 cm)", 'Distancia': '1.52', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Altavoces': '2', 'HDMI': '3'}
# {'Modelo': "TV XIAOMI MI P1 (LED - 55'' - 140 cm - 4K Ultra HD - Smart TV)", 'Precio': '469,99€', 'Tamaño': "55'' (140 cm)", 'Distancia': '1.68', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20', 'Altavoces': '2', 'HDMI': '3'}
# {'Modelo': "TV LG 65NANO756 (Nano Cell - 65'' - 165 cm - 4K Ultra HD - Smart TV)", 'Precio': '749,00€', 'Tamaño': "65'' (165 cm)", 'Distancia': '1.98', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV HISENSE 55A7GQ (QLED - 55'' - 140 cm - 4K Ultra HD - Smart TV)", 'Precio': '529,99€', 'Tamaño': "55'' (140 cm)", 'Distancia': '1.68', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV HISENSE 55U8GQ (ULED - 55'' - 140 cm - 4K Ultra HD - Smart TV)", 'Precio': '699,99€', 'Tamaño': "55'' (140 cm)", 'Distancia': '1.68', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '2*10W+20W+2*10W', 'Altavoces': 'Sí', 'HDMI': '4'}
# {'Modelo': "TV SAMSUNG QE75Q70 (QLED - 75'' - 189 cm - 4K Ultra HD - Smart TV)", 'Precio': '1384,60€', 'Tamaño': "75'' (189 cm)", 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '4'}
# {'Modelo': "TV SAMSUNG QE65Q950TST (QLED - 65'' - 165 cm - 8K Ultra HD - Smart TV)", 'Precio': '2203,90€', 'Tamaño': "65'' (165 cm)", 'Distancia': '2', 'Tecnología': 'LCD-LED', 'Resolución': '8K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '70 W', 'Altavoces': '4.2.2', 'HDMI': '4'}
# {'Modelo': "TV SAMSUNG QE65Q950TST (QLED - 65'' - 165 cm - 8K Ultra HD - Smart TV)", 'Precio': '2203,90€', 'Tamaño': "65'' (165 cm)", 'Distancia': '2', 'Tecnología': 'LCD-LED', 'Resolución': '8K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '70 W', 'Altavoces': '4.2.2', 'HDMI': '4'}
# {'Modelo': "TV LG 77G16 (OLED - 77'' - 196 cm - 4K Ultra HD - Smart TV)", 'Precio': '6038,99€', 'Tamaño': "77'' (196 cm)", 'Distancia': '2.35', 'Tecnología': 'OLED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '60 W', 'Altavoces': '4.2', 'HDMI': '4'}
# {'Modelo': "TV SONY XR75X90J (LED - 75'' - 189 cm - 4K Ultra HD - Smart TV)", 'Precio': '1659,00€', 'Tamaño': "75'' (189 cm)", 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '2.0', 'HDMI': '4'}
# {'Modelo': "TV LG 65NANO886PB (Nano Cell - 65'' - 165 cm - 4K Ultra HD - Smart TV)", 'Precio': '999,00€', 'Tamaño': "65'' (165 cm)", 'Distancia': '1.98', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '4'}
# {'Modelo': "TV HISENSE 50A7GQ (QLED - 50'' - 127 cm - 4K Ultra HD - Smart TV)", 'Precio': '475,99€', 'Tamaño': "50'' (127 cm)", 'Distancia': '1.52', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV SONY XR50X90J (LED - 50'' - 127 cm - 4K Ultra HD - Smart TV)", 'Precio': '899,99€', 'Tamaño': "50'' (127 cm)", 'Distancia': '1.52', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '2.0', 'HDMI': '4'}
# {'Modelo': "TV SONY XR55A80J (OLED - 55'' - 140 cm - 4K Ultra HD - Smart TV)", 'Precio': '1508,80€', 'Tamaño': "55'' (140 cm)", 'Distancia': '1.68', 'Tecnología': 'OLED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '30 W', 'HDMI': '4'}
# {'Modelo': "TV SAMSUNG UE55AU7172U (LED - 55'' - 140 cm - 4K Ultra HD - Smart TV)", 'Precio': '537,65€', 'Tamaño': "55'' (140 cm)", 'Distancia': '1.68', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV SAMSUNG QE75QN800A (Neo QLED - 75'' - 189 cm - 8K Ultra HD - Smart TV)", 'Precio': '4999,00€', 'Tamaño': "75'' (189 cm)", 'Tecnología': 'LCD-LED', 'Resolución': '8K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '70 W', 'Altavoces': '4.2.2', 'HDMI': '4'}
# {'Modelo': "TV LG 82UP80006LA (LED - 82'' - 208 cm - 4K Ultra HD - Smart TV)", 'Precio': '1295,00€', 'Tamaño': "82'' (208 cm)", 'Distancia': '2.5', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '4'}
# {'Modelo': "TV PHILIPS 43PUS7956 (LED - 43'' - 109 cm - 4K Ultra HD - Smart TV)", 'Precio': '419,99€', 'Tamaño': "43'' (109 cm)", 'Distancia': '1.31', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '4'}
# {'Modelo': "TV LG 75UP80006LA (LED - 75'' - 191 cm - 4K Ultra HD - Smart TV)", 'Precio': '895,00€', 'Tamaño': "75'' (191 cm)", 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV PHILIPS 50PUS7956 (LED - 50'' - 127 cm - 4K Ultra HD - Smart TV)", 'Precio': '459,00€', 'Tamaño': "50'' (127 cm)", 'Distancia': '1.52', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '4'}
# {'Modelo': "TV LG 49UN711 (LED - 49'' 124 cm - 4k Ultra HD - Smart TV)", 'Precio': '409,00€', 'Tamaño': "49'' (124 cm)", 'Resolución': '4K Ultra HD', 'Smart TV': 'yes'}
# {'Modelo': "TV SAMSUNG UE50AU7175 (LED - 50'' - 127 cm - 4K Ultra HD - Smart TV)", 'Precio': '459,00€', 'Tamaño': "50'' (127 cm)", 'Distancia': '1.52', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV SAMSUNG QE65QN95A (Neo QLED - 65'' - 165 cm - 4K Ultra HD - Smart TV)", 'Precio': '2194,99€', 'Tamaño': "65'' (165 cm)", 'Distancia': '1.98', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '70 W', 'Altavoces': '4.2.2', 'HDMI': '4'}
# {'Modelo': "TV HISENSE 65A7GQ (QLED - 65'' - 165 cm - 4K Ultra HD - Smart TV)", 'Precio': '718,00€', 'Tamaño': "65'' (165 cm)", 'Distancia': '1.98', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV CHIQ L40H7N (LED - 40'' - Full HD - Smart TV)", 'Precio': '245,99€', 'Tamaño': "40'' (102 cm)", 'Tecnología': 'LED', 'Resolución': 'Full HD', 'Smart TV': 'Sí', 'HDMI': '3'}
# {'Modelo': "TV SILVER 411336 (LED - 40'' - 102 cm - HD - Smart TV)", 'Precio': '356,76€', 'Tamaño': "40'' (102 cm)", 'Distancia': '1.5', 'Tecnología': 'LCD-LED', 'Resolución': 'HD / HD Ready', 'Smart TV': 'Sí', 'Sonido': '16 W', 'Altavoces': '2.0', 'HDMI': '2'}
# {'Modelo': "TV SONY KD-85X85J (LED - 85'' - 216 cm - 4K Ultra HD - Smart TV)", 'Precio': '2229,00€', 'Tamaño': "85'' (216 cm)", 'Distancia': '2.59', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '4'}
# {'Modelo': "TV PHILIPS 43PUS8536 (LED - 43'' - 109 cm - 4K Ultra HD - Smart TV)", 'Precio': '559,99€', 'Tamaño': "43'' (109 cm)", 'Distancia': '1.31', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '4'}
# {'Modelo': "TV SILVER 409213 (LED - 65'' - 165 cm - 4K Ultra HD - Smart TV)", 'Precio': '746,95€', 'Tamaño': "65'' (165 cm)", 'Distancia': '1.98', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'HDMI': '3'}
# {'Modelo': "TV SAMSUNG UE55TU7025 (LED - 55'' - 140 cm - 4K Ultra HD - Smart TV)", 'Precio': '629,99€', 'Tamaño': "55'' (140 cm)", 'Distancia': '1.68', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'HDMI': '2'}
# {'Modelo': "TV SONY XR65X95J (LED - 65'' - 165 cm - 4K Ultra HD - Smart TV)", 'Precio': '1829,00€', 'Tamaño': "65'' (165 cm)", 'Distancia': '1.98', 'Tecnología': 'LCD', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '50 W', 'HDMI': '4'}
# {'Modelo': "TV SONY KD50X81J (LED - 50'' - 127 cm - 4K Ultra HD - Smart TV)", 'Precio': '679,99€', 'Tamaño': "50'' (127 cm)", 'Distancia': '1.52', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '4'}
# {'Modelo': "TV SONY KD43XF8596BAEP (Caja Abierta - LED - 43'' - 109 cm - 4K Ultra HD - Smart TV)", 'Precio': '384,47€', 'Tamaño': "43'' (109 cm)", 'Distancia': '1.31', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '4'}
# {'Modelo': "TV SAMSUNG UE75AU9005 (LED - 75'' - 189 cm - 4K Ultra HD - Smart TV)", 'Precio': '1217,99€', 'Tamaño': "75'' (189 cm)", 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2', 'HDMI': '3'}
# {'Modelo': "TV HISENSE 65A7100F (LED - 65'' - 165 cm - 4K Ultra HD - Smart TV)", 'Precio': '589,99€', 'Tamaño': "65'' (165 cm)", 'Distancia': '1.98', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '16 W', 'Altavoces': '2', 'HDMI': '3'}
# {'Modelo': "TV PHILIPS 50PUS8536 (LED - 50'' - 127 cm - 4K Ultra HD - Smart TV)", 'Precio': '669,99€', 'Tamaño': "50'' (127 cm)", 'Distancia': '1.52', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '4'}
# {'Modelo': "TV SONY XR65X90J (LED - 65'' - 165 cm - 4K Ultra HD - Smart TV)", 'Precio': '1159,00€', 'Tamaño': "65'' (165 cm)", 'Distancia': '1.98', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '2.0', 'HDMI': '4'}
# {'Modelo': "TV LG 50NANO886PB (Nano Cell - 50'' - 127 cm - 4K Ultra HD - Smart TV)", 'Precio': '1183,19€', 'Tamaño': "50'' (127 cm)", 'Distancia': '1.52', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '4'}
# {'Modelo': "TV LG 55NANO886PB (Nano Cell - 55'' - 140 cm - 4K Ultra HD - Smart TV)", 'Precio': '845,00€', 'Tamaño': "55'' (140 cm)", 'Distancia': '1.68', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '4'}
# {'Modelo': "TV SAMSUNG UE43AU9005 (LED - 43'' - 109 cm - 4K Ultra HD - Smart TV)", 'Precio': '596,99€', 'Tamaño': "43'' (109 cm)", 'Distancia': '1.31', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2', 'HDMI': '3'}
# {'Modelo': "TV PHILIPS 43PUS7406 (LED - 43'' - 109 cm - 4K Ultra HD - Smart TV)", 'Precio': '389,99€', 'Tamaño': "43'' (109 cm)", 'Distancia': '1.31', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '4'}
# {'Modelo': "TV SONY KD55X81J (LED - 55'' - 140 cm - 4K Ultra HD - Smart TV)", 'Precio': '759,99€', 'Tamaño': "55'' (140 cm)", 'Distancia': '1.68', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '4'}
# {'Modelo': "TV LG 50UP81006 (LED - 50'' - 127 cm - 4K Ultra HD - Smart TV)", 'Precio': '578,99€', 'Tamaño': "50'' (127 cm)", 'Distancia': '1.52', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV SAMSUNG QE65Q70RATXXC (Caja Abierta - QLED - 65'' - 165 cm - 4K Ultra HD - Smart TV)", 'Precio': '847,47€', 'Tamaño': "65'' (165 cm)", 'Resolución': '4K Ultra HD', 'Smart TV': 'Apps y Web Browsing', 'HDMI': '4'}
# {'Modelo': "TV HISENSE 55U7QF (ULED Quantum Dot - 55'' - 140 cm - 4K Ultra HD - Smart TV)", 'Precio': '516,90€', 'Tamaño': "55'' (140 cm)", 'Distancia': '1.68', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '10 W', 'Altavoces': '2.0', 'HDMI': '4'}
# {'Modelo': "TV LG OLED88Z19 (OLED - 88'' - 224 cm - 8K Ultra HD - Smart TV)", 'Precio': '24599,00€', 'Tamaño': "88'' (224 cm)", 'Distancia': '2.8', 'Tecnología': 'OLED', 'Resolución': '8K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '80 W', 'Altavoces': '4.2', 'HDMI': '4'}
# {'Modelo': "TV HISENSE 43A7100F (LED - 43'' - 109 cm - 4K Ultra HD - Smart TV)", 'Precio': '340,99€', 'Tamaño': "43'' (109 cm)", 'Distancia': '1.2', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Altavoces': '2', 'HDMI': '3'}
# {'Modelo': "TV HISENSE 65U8GQ (ULED - 65'' - 165 cm - 4K Ultra HD - Smart TV)", 'Precio': '979,99€', 'Tamaño': "65'' (165 cm)", 'Distancia': '1.98', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '2*10W+20W+2*10W', 'Altavoces': 'Sí', 'HDMI': '4'}
# {'Modelo': "TV PHILIPS 50PUS7406 (LED - 50'' - 127 cm - 4K Ultra HD - Smart TV)", 'Precio': '459,99€', 'Tamaño': "50'' (127 cm)", 'Distancia': '1.52', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '4'}
# {'Modelo': "TV HISENSE 75A7GQ (QLED - 75'' - 189 cm - 4K Ultra HD - Smart TV)", 'Precio': '999,00€', 'Tamaño': "75'' (189 cm)", 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '30 W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV SAMSUNG QE50Q60A (QLED - 50'' - 127 cm - 4K Ultra HD - Smart TV)", 'Precio': '719,99€', 'Tamaño': "50'' (127 cm)", 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV SONY XR55A90JAEP (OLED - 55'' - 140 cm - 4K Ultra HD - Smart TV)", 'Precio': '2660,62€', 'Tamaño': "55'' (140 cm)", 'Distancia': '1.68', 'Tecnología': 'OLED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '60 W', 'HDMI': '4'}
# {'Modelo': 'Proyector LG HU810PW (Láser - 4K Ultra HD - Smart TV)', 'Precio': '2399,00€', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '10 W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV SAMSUNG UE65TU7025 (LED - 65'' - 165 cm - 4K Ultra HD - Smart TV)", 'Precio': '743,77€', 'Tamaño': "65'' (165 cm)", 'Distancia': '1.98', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'HDMI': '2'}
# {'Modelo': "TV SAMSUNG QE65Q700T (QLED - 65'' - 165 cm - 8K Ultra HD - Smart TV)", 'Precio': '2619,77€', 'Tamaño': "65'' (165 cm)", 'Distancia': '2', 'Tecnología': 'LCD-LED', 'Resolución': '8K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '60 W', 'Altavoces': '4.2.2', 'HDMI': '4'}
# {'Modelo': "TV LG 43NANO776PA (Nano Cell - 43'' - 109 cm - 4K Ultra HD - Smart TV)", 'Precio': '482,81€', 'Tamaño': "43'' (109 cm)", 'Distancia': '1.31', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV LG 65UP80006L (LED - 65'' - 165 cm - 4K Ultra HD - Smart TV)", 'Precio': '699,00€', 'Tamaño': "65'' (165 cm)", 'Distancia': '1.98', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '3'}
# {'Modelo': "TV SAMSUNG UE50TU7025 (LED - 50'' - 127 cm - 4K Ultra HD - Smart TV)", 'Precio': '582,01€', 'Tamaño': "50'' (127 cm)", 'Distancia': '1.52', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20W', 'Altavoces': '2', 'HDMI': '2'}
# {'Modelo': "TV SAMSUNG UE75TU7025 (LED - 75'' - 189 cm - 4K Ultra HD - Smart TV)", 'Precio': '1099,00€', 'Tamaño': "75'' (189 cm)", 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20W', 'Altavoces': '2.0', 'HDMI': '2'}
# {'Modelo': "TV HISENSE 43A7500F (LED - 43'' - 109 cm - 4K Ultra HD - Smart TV)", 'Precio': '405,97€', 'Tamaño': "43'' (109 cm)", 'Distancia': '1.31', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '14 W', 'Altavoces': '2.0', 'HDMI': '4'}
# {'Modelo': "TV SONY KD-43XH8596 (Caja Abierta - LED - 43'' - 109 cm - 4K Ultra HD - Smart TV)", 'Precio': '445,77€', 'Tamaño': "43'' (109 cm)", 'Distancia': '1.31', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '4'}
# {'Modelo': "TV LG 55SJ810V (Caja Abierta - LED - 55'' - 140 cm - 4K Ultra HD - Smart TV)", 'Precio': '497,97€', 'Tamaño': "55'' (140 cm)", 'Resolución': '4K Ultra HD', 'Smart TV': 'Apps y Web Browsing', 'Altavoces': 'Sí', 'HDMI': '4'}
# {'Modelo': "TV SONY KD43X81J (LED - 43'' - 109 cm - 4K Ultra HD - Smart TV)", 'Precio': '599,99€', 'Tamaño': "43'' (109 cm)", 'Distancia': '1.31', 'Tecnología': 'LCD-LED', 'Resolución': '4K Ultra HD', 'Smart TV': 'Sí', 'Sonido': '20 W', 'Altavoces': '2.0', 'HDMI': '4'}

# %%
df = pd.DataFrame(televisiones)

# %%
df
# Out:
#                                                Modelo    Precio  \
# 0   TV LG 55C15 (OLED - 55'' - 140 cm - 4K Ultra H...  1249,00€
# 1   TV LG 65C15 (OLED - 65'' - 165 cm - 4K Ultra H...  1599,00€
# 2   TV LG 48C15 (OLED - 48'' - 122 cm - 4K Ultra H...  1890,89€
# 3   TV LG 55G16 (OLED - 55'' - 140 cm - 4K Ultra H...  1495,00€
# 4   TV LG 55UP77006LB (LED - 55'' - 140 cm - 4K Ul...   469,00€
# ..                                                ...       ...
# 93  TV SAMSUNG UE75TU7025 (LED - 75'' - 189 cm - 4...  1099,00€
# 94  TV HISENSE 43A7500F (LED - 43'' - 109 cm - 4K ...   405,97€
# 95  TV SONY KD-43XH8596 (Caja Abierta - LED - 43''...   445,77€
# 96  TV LG 55SJ810V (Caja Abierta - LED - 55'' - 14...   497,97€
# 97  TV SONY KD43X81J (LED - 43'' - 109 cm - 4K Ult...   599,99€
#
#            Tamaño Distancia Tecnología   Resolución             Smart TV  \
# 0   55'' (140 cm)      1.68       OLED  4K Ultra HD                   Sí
# 1   65'' (165 cm)      1.98       OLED  4K Ultra HD                   Sí
# 2   48'' (122 cm)      1.49       OLED  4K Ultra HD                   Sí
# 3   55'' (140 cm)      1.68       OLED  4K Ultra HD                   Sí
# 4   55'' (140 cm)      1.68    LCD-LED  4K Ultra HD                   Sí
# ..            ...       ...        ...          ...                  ...
# 93  75'' (189 cm)       NaN    LCD-LED  4K Ultra HD                   Sí
# 94  43'' (109 cm)      1.31    LCD-LED  4K Ultra HD                   Sí
# 95  43'' (109 cm)      1.31    LCD-LED  4K Ultra HD                   Sí
# 96  55'' (140 cm)       NaN        NaN  4K Ultra HD  Apps y Web Browsing
# 97  43'' (109 cm)      1.31    LCD-LED  4K Ultra HD                   Sí
#
#    Sonido Altavoces HDMI
# 0    40 W       2.2    4
# 1    40 W       2.2    4
# 2    40 W       2.2    4
# 3    60 W       4.2    4
# 4    20 W       2.0    2
# ..    ...       ...  ...
# 93    20W       2.0    2
# 94   14 W       2.0    4
# 95   20 W       2.0    4
# 96    NaN        Sí    4
# 97   20 W       2.0    4
#
# [98 rows x 10 columns]

# %%
df['Marca'] =[modelo.split()[1] for modelo in df['Modelo']]

# %%
df['Precio'] = [float('.'.join(precio.rstrip('€').split(','))) for precio in df['Precio']]

# %%
df['Tamaño'] = [str(pulgadas).split()[0].strip("'") for pulgadas in df['Tamaño']]

# %%
df['Tamaño'][5].split()[0].strip("'")
# Out:
# '5'

# %%
df.to_csv('teles.csv')
